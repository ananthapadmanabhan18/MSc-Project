# %% [markdown]
# # **Plots for $\pi^+$**

# %%
import ROOT
file_mci = ROOT.TFile("/home/apmnair18/Documents/MSc_Project/Analysis_outputs/pdg211_nevents250/MCInfo__1.root")
file_analysis = ROOT.TFile("/home/apmnair18/Documents/MSc_Project/Analysis_outputs/pdg211_nevents250/analysis__1.root")
file_clustering = ROOT.TFile("/home/apmnair18/Documents/MSc_Project/Analysis_outputs/pdg211_nevents250/clusters__1.root")
tree_mci = file_mci.Get("MCInfo")
tree_analysis = file_analysis.Get("analysis")
tree_clustering = file_clustering.Get("clusters")

# %% [markdown]
# ## Vx vs Vy Distribution

# %%
canvas = True
canvas = ROOT.TCanvas("canvas for X-Y", "canvas", 500, 400)
tree_mci.Draw("Vx:Vy", "", "colz")
canvas.SetTitle("Vx vs Vy for $\pi^0$")
canvas.Draw()

# %% [markdown]
# ## Energy Distribution

# %%
canvas=True
canvas = ROOT.TCanvas("canvas for Energy", "canvas", 700, 450)
tree_analysis.Draw("Energy")
canvas.SetTitle("Energy for $\pi^0$")
canvas.Draw()

# %% [markdown]
# ## Transverse Momentum Distribution

# %%
canvas = True
canvas = ROOT.TCanvas("canvas for pt", "canvas", 700, 450)
tree_analysis.Draw("Pt")
canvas.SetTitle("p_t for $\pi^0$")
canvas.Draw()
